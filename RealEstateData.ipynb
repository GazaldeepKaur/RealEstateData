# %%
import openpyxl

# %%
wb=openpyxl.load_workbook(r'C:\Users\Lenovo\Downloads\realestatedata (1).xlsx')

# %%
print(wb)

# %%
sheet=wb.sheetnames
print(sheet)
# Out:
# ['stouffville', 'peter']

# %%
for x in sheet:
    print(x)
# Out:
# stouffville
# peter

# %%
realestatedata=wb['stouffville']

data1=realestatedata['A2']
print(data1.value)
# Out:
# Detached

# %%
for i in range(1, 190):
    print(realestatedata.cell(row=i, column=10).value)
# Out:
# SoldDate
# None
# 2/3/2021
# 3/8/2021
# 1/18/2021
# 2/24/2021
# 2/15/2021
# 3/29/2021
# 2/17/2021
# 3/18/2021
# 2/17/2021
# 3/14/2021
# 3/22/2021
# None
# 2/22/2021
# None
# 3/23/2021
# 1/13/2021
# 3/20/2021
# None
# 2/11/2021
# 3/11/2021
# 1/22/2021
# 3/16/2021
# 2/8/2021
# 1/1/2021
# 3/22/2021
# 2/25/2021
# 3/5/2021
# 1/8/2021
# 3/18/2021
# None
# 1/27/2021
# 2/1/2021
# 2/28/2021
# 3/15/2021
# None
# 3/9/2021
# 3/20/2021
# None
# 3/8/2021
# 3/8/2021
# 3/23/2021
# None
# None
# 3/23/2021
# 2/18/2021
# 3/11/2021
# 2/3/2021
# None
# 2/14/2021
# 1/21/2021
# None
# None
# None
# 3/7/2021
# 1/8/2021
# None
# 1/15/2021
# None
# 2/27/2021
# 2/18/2021
# 3/22/2021
# 2/16/2021
# 1/27/2021
# 3/18/2021
# None
# None
# 2/8/2021
# None
# None
# 2/15/2021
# 1/22/2021
# 12/31/2020
# 2/4/2021
# 2/2/2021
# 2/2/2021
# 2/4/2021
# 3/5/2021
# 3/2/2021
# 2/18/2021
# 2/8/2021
# 3/5/2021
# 1/9/2021
# None
# 3/14/2021
# None
# None
# 3/17/2021
# 3/25/2021
# 3/14/2021
# 3/30/2021
# None
# None
# 3/4/2021
# ...

# %%
whitbyredata=['start']
tpl_struct=()
for i in range(1, 190):
    type1=realestatedata.cell(row=i, column=1).value;
    #print(type1);
    description=realestatedata.cell(row=i, column=2).value;
    #print(description);
    bedrooms=realestatedata.cell(row=i, column=3).value;
    #print(bedrooms);
    price=realestatedata.cell(row=i, column=4).value;
    #print(price);
    
    tpl_struct=(type1, description, bedrooms, price)
    whitbyredata.append(tpl_struct)
    

for x in whitbyredata:
    if x[0]=='Detached':
        print(x)
# Out:
# ('Detached', '2-Storey', 4, None)
# ('Detached', '2-Storey', 3, 999000)
# ('Detached', '2-Storey', 3, 1000000)
# ('Detached', '2-Storey', 4, 1300800)
# ('Detached', 'Bungalow', 3, 860000)
# ('Detached', '2-Storey', 3, 950000)
# ('Detached', 'Bungalow', 3, 980000)
# ('Detached', 'Bungalow', 3, 953000)
# ('Detached', '2-Storey', 4, 1380000)
# ('Detached', '2-Storey', 3, 1210000)
# ('Detached', 'Bungaloft', 3, 1151000)
# ('Detached', '2-Storey', 3, 998000)
# ('Detached', '2-Storey', 4, 1200000)
# ('Detached', '2-Storey', 4, 1170000)
# ('Detached', '2-Storey', 4, None)
# ('Detached', '2-Storey', 3, 990000)
# ('Detached', '2-Storey', 3, 1240000)
# ('Detached', '2-Storey', 4, 1385000)
# ('Detached', '2-Storey', 4, 1550000)
# ('Detached', '2-Storey', 4, 1788000)
# ('Detached', '2-Storey', 4, 1310000)
# ('Detached', '2-Storey', 4, 2025000)
# ('Detached', '3-Storey', 5, None)
# ('Detached', '2-Storey', 3, None)
# ('Detached', '2-Storey', 4, 978900)
# ('Detached', '2-Storey', 3, 997000)
# ...
